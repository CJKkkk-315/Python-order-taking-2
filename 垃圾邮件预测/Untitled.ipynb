# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5,5)
y = 5*x*x-1*x+1

ax = plt.gca()

plt.plot(x, y, color="blue")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.2, 5, 100)
y = 1/x

plt.plot(x,y)
plt.plot(-x,-y)
plt.show()
