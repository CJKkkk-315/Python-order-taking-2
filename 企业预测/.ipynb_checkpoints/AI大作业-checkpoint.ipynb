# %%
#导入数据
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
#展示所有行
pd.set_option('display.max_columns', None)

# %%
#读取training_data
data = pd.read_csv('D:/Fintec_Class/ML/ml_case_data/ml_case_training_data.csv')
data.head()
# Out:
#                                  id                      activity_new  \
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN
# 4  bba03439a292a1e166f80264c16191cb                               NaN
#
#    campaign_disc_ele                     channel_sales  cons_12m  \
# 0                NaN  lmkebamcaaclubfxadlmueccxoimlema    309275
# 1                NaN  foosdfpfkusacimwkcsosbicdxkicaua         0
# 2                NaN                               NaN      4660
# 3                NaN  foosdfpfkusacimwkcsosbicdxkicaua       544
# 4                NaN  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#    cons_gas_12m  cons_last_month  date_activ    date_end date_first_activ  \
# 0             0            10025  2012-11-07  2016-11-06              NaN
# 1         54946                0  2013-06-15  2016-06-15              NaN
# 2             0                0  2009-08-21  2016-08-30              NaN
# 3             0                0  2010-04-16  2016-04-16              NaN
# 4             0                0  2010-03-30  2016-03-30              NaN
#
#   date_modif_prod date_renewal  forecast_base_bill_ele  \
# 0      2012-11-07   2015-11-09                     NaN
# 1             NaN   2015-06-23                     NaN
# 2      2009-08-21   2015-08-31                     NaN
# 3      2010-04-16   2015-04-17                     NaN
# 4      2010-03-30   2015-03-31                     NaN
#
#    forecast_base_bill_year  forecast_bill_12m  forecast_cons  \
# 0                      NaN                NaN            NaN
# 1                      NaN                NaN            NaN
# 2                      NaN                NaN            NaN
# 3                      NaN                NaN            NaN
# 4                      NaN                NaN            NaN
#
#    forecast_cons_12m  forecast_cons_year  forecast_discount_energy  \
# 0           26520.30               10025                       0.0
# 1               0.00                   0                       0.0
# 2             189.95                   0                       0.0
# 3              47.96                   0                       0.0
# 4             240.04                   0                       0.0
#
#    forecast_meter_rent_12m  forecast_price_energy_p1  \
# 0                   359.29                  0.095919
# 1                     1.78                  0.114481
# 2                    16.27                  0.145711
# 3                    38.72                  0.165794
# 4                    19.83                  0.146694
#
#    forecast_price_energy_p2  forecast_price_pow_p1 has_gas  imp_cons  \
# 0                  0.088347              58.995952       f     831.8
# 1                  0.098142              40.606701       t       0.0
# 2                  0.000000              44.311378       f       0.0
# 3                  0.087899              44.311378       f       0.0
# 4                  0.000000              44.311378       f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# 0                -41.76              -41.76            1     1732.36
# 1                 25.44               25.44            2      678.99
# 2                 16.38               16.38            1       18.89
# 3                 28.60               28.60            1        6.60
# 4                 30.22               30.22            1       25.46
#
#    num_years_antig                         origin_up  pow_max
# 0                3  ldkssxwpmemidmecebumciepifcamkci  180.000
# 1                3  lxidpiddsbxsbosboudacockeimpuepw   43.648
# 2                6  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.800
# 3                6  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.856
# 4                6  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.200

# %%
#将数据中的零值变为空值
data = data.replace(0,np.nan)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   activity_new              6551 non-null   object
#  2   campaign_disc_ele         0 non-null      float64
#  3   channel_sales             11878 non-null  object
#  4   cons_12m                  15970 non-null  float64
#  5   cons_gas_12m              2926 non-null   float64
#  6   cons_last_month           10873 non-null  float64
#  7   date_activ                16096 non-null  object
#  8   date_end                  16094 non-null  object
#  9   date_first_activ          3508 non-null   object
#  10  date_modif_prod           15939 non-null  object
#  11  date_renewal              16056 non-null  object
#  12  forecast_base_bill_ele    2065 non-null   float64
#  13  forecast_base_bill_year   2065 non-null   float64
#  14  forecast_bill_12m         3443 non-null   float64
#  15  forecast_cons             1994 non-null   float64
#  16  forecast_cons_12m         15762 non-null  float64
#  17  forecast_cons_year        9598 non-null   float64
#  18  forecast_discount_energy  579 non-null    float64
#  19  forecast_meter_rent_12m   15281 non-null  float64
#  20  forecast_price_energy_p1  15946 non-null  float64
#  21  forecast_price_energy_p2  8743 non-null   float64
#  22  forecast_price_pow_p1     15870 non-null  float64
#  23  has_gas                   16096 non-null  object
#  24  imp_cons                  9575 non-null   float64
#  25  margin_gross_pow_ele      15907 non-null  float64
#  26  margin_net_pow_ele        15914 non-null  float64
#  27  nb_prod_act               16096 non-null  int64
#  28  net_margin                15876 non-null  float64
#  29  num_years_antig           16096 non-null  int64
#  30  origin_up                 16009 non-null  object
#  31  pow_max                   16093 non-null  float64
# dtypes: float64(20), int64(2), object(10)
# memory usage: 3.9+ MB

# %%
#删除缺失值达到20%的变量
val_num = len(data.columns)
val_miss = {}
val_all = data.isnull().sum()
for i in range(val_num):
    if val_all[i] != 0:
        val_miss[data.columns[i]]=val_all[i]
val_miss_names = list(val_miss.keys())
data_num = len(data)
for i in range(len(val_miss)):
    if val_miss[val_miss_names[i]]>0.2*data_num:
        print('删除'+val_miss_names[i])
        data = data.drop(val_miss_names[i],axis=1)
# Out:
# 删除activity_new
# 删除campaign_disc_ele
# 删除channel_sales
# 删除cons_gas_12m
# 删除cons_last_month
# 删除date_first_activ
# 删除forecast_base_bill_ele
# 删除forecast_base_bill_year
# 删除forecast_bill_12m
# 删除forecast_cons
# 删除forecast_cons_year
# 删除forecast_discount_energy
# 删除forecast_price_energy_p2
# 删除imp_cons

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   cons_12m                  15970 non-null  float64
#  2   date_activ                16096 non-null  object
#  3   date_end                  16094 non-null  object
#  4   date_modif_prod           15939 non-null  object
#  5   date_renewal              16056 non-null  object
#  6   forecast_cons_12m         15762 non-null  float64
#  7   forecast_meter_rent_12m   15281 non-null  float64
#  8   forecast_price_energy_p1  15946 non-null  float64
#  9   forecast_price_pow_p1     15870 non-null  float64
#  10  has_gas                   16096 non-null  object
#  11  margin_gross_pow_ele      15907 non-null  float64
#  12  margin_net_pow_ele        15914 non-null  float64
#  13  nb_prod_act               16096 non-null  int64
#  14  net_margin                15876 non-null  float64
#  15  num_years_antig           16096 non-null  int64
#  16  origin_up                 16009 non-null  object
#  17  pow_max                   16093 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 2.2+ MB

# %%
data['date_end'].isnull()[2]
# Out:
# False

# %%
#求合同开始和结束的间隔天数，单独的日期没有实际意义。
data['days']=0
def cal_days(data):
    for i in range(len(data)):
        if data['date_end'].isnull()[i]==False:
            start_time = data['date_activ'][i]
            end_time = data['date_end'][i]
            start = time.mktime(time.strptime(start_time,'%Y-%m-%d'))
            end = time.mktime(time.strptime(end_time,'%Y-%m-%d'))
            data['days'][i] = int((end - start)/(24*60*60))
        else:
            data['days'][i] = np.nan
cal_days(data)
#data.drop(['date_activ','date_end'],axis=1,inplace=True)
data.head()
# Out:
# C:\Users\xrheng\AppData\Local\Temp/ipykernel_2012/139553997.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['days'][i] = int((end - start)/(24*60*60))
# C:\Users\xrheng\AppData\Local\Temp/ipykernel_2012/139553997.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['days'][i] = np.nan
# C:\Users\xrheng\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                  id  cons_12m  date_activ    date_end  \
# 0  48ada52261e7cf58715202705a0451c9  309275.0  2012-11-07  2016-11-06
# 1  24011ae4ebbe3035111d65fa7c15bc57       NaN  2013-06-15  2016-06-15
# 2  d29c2c54acc38ff3c0614d0a653813dd    4660.0  2009-08-21  2016-08-30
# 3  764c75f661154dac3a6c254cd082ea7d     544.0  2010-04-16  2016-04-16
# 4  bba03439a292a1e166f80264c16191cb    1584.0  2010-03-30  2016-03-30
#
#   date_modif_prod date_renewal  forecast_cons_12m  forecast_meter_rent_12m  \
# 0      2012-11-07   2015-11-09           26520.30                   359.29
# 1             NaN   2015-06-23                NaN                     1.78
# 2      2009-08-21   2015-08-31             189.95                    16.27
# 3      2010-04-16   2015-04-17              47.96                    38.72
# 4      2010-03-30   2015-03-31             240.04                    19.83
#
#    forecast_price_energy_p1  forecast_price_pow_p1 has_gas  \
# 0                  0.095919              58.995952       f
# 1                  0.114481              40.606701       t
# 2                  0.145711              44.311378       f
# 3                  0.165794              44.311378       f
# 4                  0.146694              44.311378       f
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# 0                -41.76              -41.76            1     1732.36
# 1                 25.44               25.44            2      678.99
# 2                 16.38               16.38            1       18.89
# 3                 28.60               28.60            1        6.60
# 4                 30.22               30.22            1       25.46
#
#    num_years_antig                         origin_up  pow_max    days
# 0                3  ldkssxwpmemidmecebumciepifcamkci  180.000  1460.0
# 1                3  lxidpiddsbxsbosboudacockeimpuepw   43.648  1096.0
# 2                6  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.800  2566.0
# 3                6  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.856  2192.0
# 4                6  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.200  2192.0

# %%
#求下一个续约日和结束的间隔天数，单独的日期没有实际意义。
data['renewal_days']=0
def cal_days(data):
    for i in range(len(data)):
        if (data['date_end'].isnull()[i]==False) and (data['date_renewal'].isnull()[i]==False):
            renewal_time = data['date_renewal'][i]
            end_time = data['date_end'][i]
            renewal = time.mktime(time.strptime(renewal_time,'%Y-%m-%d'))
            end = time.mktime(time.strptime(end_time,'%Y-%m-%d'))
            data['renewal_days'][i] = int((renewal-end)/(24*60*60))
        else:
            data['renewal_days'][i] = np.nan
cal_days(data)
#data.drop(['renewal_days','date_end'],axis=1,inplace=True)
data.head(60)
# Out:
# C:\Users\xrheng\AppData\Local\Temp/ipykernel_2012/1948964105.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data
# 7         -365.0
# 8         -365.0
# 9         -365.0
# 10        -364.0
# 11        -365.0
# 12        -365.0
# 13        -365.0
# 14        -364.0
# 15        -364.0
# 16        -365.0
# 17        -365.0
# 18        -365.0
# 19        -364.0
# 20        -364.0
# 21        -362.0
# 22        -363.0
# 23        -364.0
# 24        -361.0
# 25        -365.0
# 26        -365.0
# 27        -355.0
# 28        -365.0
# 29        -365.0
# 30        -364.0
# 31        -364.0
# 32        -365.0
# 33        -363.0
# 34        -364.0
# 35        -579.0
# 36        -365.0
# 37        -365.0
# 38        -365.0
# 39        -365.0
# 40        -365.0
# 41        -365.0
# 42        -351.0
# 43        -365.0
# 44        -365.0
# 45        -932.0
# 46        -363.0
# 47        -357.0
# 48        -365.0
# 49        -365.0
# 50        -365.0
# 51        -365.0
# 52        -363.0
# 53        -363.0
# 54        -365.0
# 55        -365.0
# 56        -364.0
# 57        -363.0
# 58        -363.0
# 59        -365.0

# %%
#判断最后一次修改处于什么阶段
#当在开始日期之前为0
#当等于开始日期时为1
#当在合同执行日期之时为2
#当超出合同日期为3
data['modif_label']=0
def cal_modif_label(data):
    for i in range(len(data)):
        if (data['date_end'].isnull()[i]==False) and (data['date_modif_prod'].isnull()[i]==False):
            start_time = data['date_activ'][i]
            date_modif_prod = data['date_modif_prod'][i]
            end_time = data['date_end'][i]
            modif = time.mktime(time.strptime(date_modif_prod,'%Y-%m-%d'))
            start = time.mktime(time.strptime(start_time,'%Y-%m-%d'))
            end = time.mktime(time.strptime(end_time,'%Y-%m-%d'))
            if modif<start:
                data['modif_label'][i] = 0
            elif modif==start:
                data['modif_label'][i] = 1
            elif modif>start and modif<=end:
                data['modif_label'][i] = 2
            elif modif>end:
                data['modif_label'][i] = 3
        else:
            data['modif_label'][i] = np.nan
cal_modif_label(data)
#data.drop(['renewal_days','date_end'],axis=1,inplace=True)
data.head(60)
# Out:
# C:\Users\xrheng\AppData\Local\Temp/ipykernel_2012/468744500.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['modif_label'][i] = 1
# C:\Users\xrheng\AppData\Local\Temp/ipykernel_2012/468744500.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['modif_label'][i] = np.nan
# C:\Users\xrheng\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                   id   cons_12m  date_activ    date_end  \
# 0   48ada52261e7cf58715202705a0451c9   309275.0  2012-11-07  2016-11-06
# 1   24011ae4ebbe3035111d65fa7c15bc57        NaN  2013-06-15  2016-06-15
# 2   d29c2c54acc38ff3c0614d0a653813dd     4660.0  2009-08-21  2016-08-30
# 3   764c75f661154dac3a6c254cd082ea7d      544.0  2010-04-16  2016-04-16
# 4   bba03439a292a1e166f80264c16191cb     1584.0  2010-03-30  2016-03-30
# 5   568bb38a1afd7c0fc49c77b3789b59a3   121335.0  2010-04-08  2016-04-08
# 6   149d57cf92fc41cf94415803a877cb4b     4425.0  2010-01-13  2016-03-07
# 7   1aa498825382410b098937d65c4ec26d     8302.0  2011-12-09  2016-12-09
# 8   7ab4bf4878d8f7661dfc20e9b8e18011    45097.0  2011-12-02  2016-12-02
# 9   01495c955be7ec5e7f3203406785aae0    29552.0  2010-04-21  2016-04-21
# 55        -365.0          1.0
# 56        -364.0          2.0
# 57        -363.0          1.0
# 58        -363.0          1.0
# 59        -365.0          1.0

# %%
origin_list = data['origin_up'].unique().tolist()
def change_list(data,origin_list):
    j = 0
    for i in origin_list:
        data.loc[data['origin_up']==i,'origin_up']=j
        j +=1
change_list(data,origin_list)
data.head()
# Out:
#                                  id  cons_12m  date_activ    date_end  \
# 0  48ada52261e7cf58715202705a0451c9  309275.0  2012-11-07  2016-11-06
# 1  24011ae4ebbe3035111d65fa7c15bc57       NaN  2013-06-15  2016-06-15
# 2  d29c2c54acc38ff3c0614d0a653813dd    4660.0  2009-08-21  2016-08-30
# 3  764c75f661154dac3a6c254cd082ea7d     544.0  2010-04-16  2016-04-16
# 4  bba03439a292a1e166f80264c16191cb    1584.0  2010-03-30  2016-03-30
#
#   date_modif_prod date_renewal  forecast_cons_12m  forecast_meter_rent_12m  \
# 0      2012-11-07   2015-11-09           26520.30                   359.29
# 1             NaN   2015-06-23                NaN                     1.78
# 2      2009-08-21   2015-08-31             189.95                    16.27
# 3      2010-04-16   2015-04-17              47.96                    38.72
# 4      2010-03-30   2015-03-31             240.04                    19.83
#
#    forecast_price_energy_p1  forecast_price_pow_p1 has_gas  \
# 0                  0.095919              58.995952       f
# 1                  0.114481              40.606701       t
# 2                  0.145711              44.311378       f
# 3                  0.165794              44.311378       f
# 4                  0.146694              44.311378       f
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# 0                -41.76              -41.76            1     1732.36
# 1                 25.44               25.44            2      678.99
# 2                 16.38               16.38            1       18.89
# 3                 28.60               28.60            1        6.60
# 4                 30.22               30.22            1       25.46
#
#    num_years_antig origin_up  pow_max    days  renewal_days  modif_label
# 0                3         0  180.000  1460.0        -363.0          1.0
# 1                3         1   43.648  1096.0        -358.0          NaN
# 2                6         2   13.800  2566.0        -365.0          1.0
# 3                6         2   13.856  2192.0        -365.0          1.0
# 4                6         2   13.200  2192.0        -365.0          1.0

# %%
data.loc[data['has_gas']=='t','has_gas']=1
data.loc[data['has_gas']=='f','has_gas']=0

# %%
#判断数据的数据类型，决定采用哪种插值方法
#data['pow_max'].value_counts()
#data['origin_up'].value_counts()
#data['date_end'].value_counts()
data['date_modif_prod'].value_counts()
# Out:
# 2015-11-01    592
# 2015-05-24    275
# 2015-12-17    202
# 2015-12-16    181
# 2015-11-18    179
#              ...
# 2011-02-19      1
# 2005-07-22      1
# 2007-04-02      1
# 2005-11-29      1
# 2015-05-08      1
# Name: date_modif_prod, Length: 2307, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   cons_12m                  15970 non-null  float64
#  2   date_activ                16096 non-null  object
#  3   date_end                  16094 non-null  object
#  4   date_modif_prod           15939 non-null  object
#  5   date_renewal              16056 non-null  object
#  6   forecast_cons_12m         15762 non-null  float64
#  7   forecast_meter_rent_12m   15281 non-null  float64
#  8   forecast_price_energy_p1  15946 non-null  float64
#  9   forecast_price_pow_p1     15870 non-null  float64
#  10  has_gas                   16096 non-null  object
#  11  margin_gross_pow_ele      15907 non-null  float64
#  12  margin_net_pow_ele        15914 non-null  float64
#  13  nb_prod_act               16096 non-null  int64
#  14  net_margin                15876 non-null  float64
#  15  num_years_antig           16096 non-null  int64
#  16  origin_up                 16009 non-null  object
#  17  pow_max                   16093 non-null  float64
#  18  days                      16094 non-null  float64
#  19  renewal_days              16056 non-null  float64
#  20  modif_label               15938 non-null  float64
# dtypes: float64(12), int64(2), object(7)
# memory usage: 2.6+ MB

# %%
#根据数据类型的不同，采用不同的方式填充数据
data.loc[data['cons_12m'].isnull(),'cons_12m']=data['cons_12m'].median()
data.loc[data['forecast_cons_12m'].isnull(),'forecast_cons_12m']=data['forecast_cons_12m'].median()
data.loc[data['forecast_meter_rent_12m'].isnull(),'forecast_meter_rent_12m']=data['forecast_meter_rent_12m'].median()
data.loc[data['forecast_price_energy_p1'].isnull(),'forecast_price_energy_p1']=data['forecast_price_energy_p1'].median()
data.loc[data['forecast_price_pow_p1'].isnull(),'forecast_price_pow_p1']=data['forecast_price_pow_p1'].median()
data.loc[data['net_margin'].isnull(),'net_margin']=data['net_margin'].median()
data.loc[data['margin_gross_pow_ele'].isnull(),'margin_gross_pow_ele']=data['margin_gross_pow_ele'].median()
data.loc[data['margin_net_pow_ele'].isnull(),'margin_net_pow_ele']=data['margin_net_pow_ele'].median()
data.loc[data['pow_max'].isnull(),'pow_max']=data['pow_max'].median()
data.loc[data['days'].isnull(),'days']=data['days'].median()
data.loc[data['renewal_days'].isnull(),'renewal_days']=data['renewal_days'].median()
data.loc[data['modif_label'].isnull(),'modif_label']=data['modif_label'].mode()[0]
data.loc[data['origin_up'].isnull(),'origin_up']=data['origin_up'].mode()[0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   cons_12m                  16096 non-null  float64
#  2   date_activ                16096 non-null  object
#  3   date_end                  16094 non-null  object
#  4   date_modif_prod           15939 non-null  object
#  5   date_renewal              16056 non-null  object
#  6   forecast_cons_12m         16096 non-null  float64
#  7   forecast_meter_rent_12m   16096 non-null  float64
#  8   forecast_price_energy_p1  16096 non-null  float64
#  9   forecast_price_pow_p1     16096 non-null  float64
#  10  has_gas                   16096 non-null  object
#  11  margin_gross_pow_ele      16096 non-null  float64
#  12  margin_net_pow_ele        16096 non-null  float64
#  13  nb_prod_act               16096 non-null  int64
#  14  net_margin                16096 non-null  float64
#  15  num_years_antig           16096 non-null  int64
#  16  origin_up                 16096 non-null  object
#  17  pow_max                   16096 non-null  float64
#  18  days                      16096 non-null  float64
#  19  renewal_days              16096 non-null  float64
#  20  modif_label               16096 non-null  float64
# dtypes: float64(12), int64(2), object(7)
# memory usage: 2.6+ MB

# %%
data.drop(['date_activ','date_end','date_modif_prod','date_renewal'],axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   cons_12m                  16096 non-null  float64
#  2   forecast_cons_12m         16096 non-null  float64
#  3   forecast_meter_rent_12m   16096 non-null  float64
#  4   forecast_price_energy_p1  16096 non-null  float64
#  5   forecast_price_pow_p1     16096 non-null  float64
#  6   has_gas                   16096 non-null  object
#  7   margin_gross_pow_ele      16096 non-null  float64
#  8   margin_net_pow_ele        16096 non-null  float64
#  9   nb_prod_act               16096 non-null  int64
#  10  net_margin                16096 non-null  float64
#  11  num_years_antig           16096 non-null  int64
#  12  origin_up                 16096 non-null  object
#  13  pow_max                   16096 non-null  float64
#  14  days                      16096 non-null  float64
#  15  renewal_days              16096 non-null  float64
#  16  modif_label               16096 non-null  float64
# dtypes: float64(12), int64(2), object(3)
# memory usage: 2.1+ MB

# %%
#读取hist_data数据
hist_data = pd.read_csv('D:/Fintec_Class/ML/ml_case_data/ml_case_training_hist_data.csv')
hist_data.head()
# Out:
#                                  id  price_date  price_p1_var  price_p2_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01      0.151367           0.0
# 1  038af19179925da21a25619c5a24b745  2015-02-01      0.151367           0.0
# 2  038af19179925da21a25619c5a24b745  2015-03-01      0.151367           0.0
# 3  038af19179925da21a25619c5a24b745  2015-04-01      0.149626           0.0
# 4  038af19179925da21a25619c5a24b745  2015-05-01      0.149626           0.0
#
#    price_p3_var  price_p1_fix  price_p2_fix  price_p3_fix
# 0           0.0     44.266931           0.0           0.0
# 1           0.0     44.266931           0.0           0.0
# 2           0.0     44.266931           0.0           0.0
# 3           0.0     44.266931           0.0           0.0
# 4           0.0     44.266931           0.0           0.0

# %%
#将数据中的零值变为空值
hist_data = hist_data.replace(0,np.nan)

# %%
#数据基础信息，有多少条
hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            193002 non-null  object
#  1   price_date    193002 non-null  object
#  2   price_p1_var  191297 non-null  float64
#  3   price_p2_var  104841 non-null  float64
#  4   price_p3_var  80168 non-null   float64
#  5   price_p1_fix  190153 non-null  float64
#  6   price_p2_fix  80013 non-null   float64
#  7   price_p3_fix  80015 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %%
#删除缺失值达到20%的变量
val_num = len(hist_data.columns)
val_miss = {}
val_all = hist_data.isnull().sum()
for i in range(val_num):
    if val_all[i] != 0:
        val_miss[hist_data.columns[i]]=val_all[i]
val_miss_names = list(val_miss.keys())
data_num = len(hist_data)
for i in range(len(val_miss)):
    if val_miss[val_miss_names[i]]>0.2*data_num:
        print('删除'+val_miss_names[i])
        hist_data = hist_data.drop(val_miss_names[i],axis=1) 
hist_data.info()
# Out:
# 删除price_p2_var
# 删除price_p3_var
# 删除price_p2_fix
# 删除price_p3_fix
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            193002 non-null  object
#  1   price_date    193002 non-null  object
#  2   price_p1_var  191297 non-null  float64
#  3   price_p1_fix  190153 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 5.9+ MB

# %%
#按照id分组，因为这个数据是每个id每12个月的数据，其他数据集每个id只有一条数据。所以求价格均值，展现一条数据，方便处理
hist_data = hist_data.groupby('id',as_index=False).mean()
hist_data.head()
# Out:
#                                  id  price_p1_var  price_p1_fix
# 0  0002203ffbb812588b632b9e628cc38d      0.124338     40.701732
# 1  0004351ebdd665e6ee664792efc4fd13      0.146426     44.385450
# 2  0010bcc39e42b3c2131ed2ce55246e3c      0.181558     45.319710
# 3  0010ee3855fdea87602a5b7aba8e42de      0.118757     40.647427
# 4  00114d74e963e47177db89bc70108537      0.147926     44.266930

# %%
#求均值后舍弃其他数据
#hist_data.drop(['price_p1_var','price_p2_var','price_p3_var','price_p1_fix','price_p2_fix','price_p3_fix'],axis=1,inplace=True)
hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            16096 non-null  object
#  1   price_p1_var  16072 non-null  float64
#  2   price_p1_fix  15975 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 377.4+ KB

# %%
#有一行有缺失值，用中位数填充
hist_data.loc[hist_data['price_p1_var'].isnull(),'price_p1_var']=hist_data['price_p1_var'].median()
hist_data.loc[hist_data['price_p1_fix'].isnull(),'price_p1_fix']=hist_data['price_p1_fix'].median()
hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            16096 non-null  object
#  1   price_p1_var  16096 non-null  float64
#  2   price_p1_fix  16096 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 377.4+ KB

# %%
#读取output数据
output_data = pd.read_csv('D:/Fintec_Class/ML/ml_case_data/ml_case_training_output.csv')
output_data.head()
# Out:
#                                  id  churn
# 0  48ada52261e7cf58715202705a0451c9      0
# 1  24011ae4ebbe3035111d65fa7c15bc57      1
# 2  d29c2c54acc38ff3c0614d0a653813dd      0
# 3  764c75f661154dac3a6c254cd082ea7d      0
# 4  bba03439a292a1e166f80264c16191cb      0

# %%
output_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16096 entries, 0 to 16095
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      16096 non-null  object
#  1   churn   16096 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 251.6+ KB

# %%
#对data和hist_data进行合并操作，内连接合并
data = pd.merge(data,hist_data,on=['id'],how='inner')
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16096 entries, 0 to 16095
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   cons_12m                  16096 non-null  float64
#  2   forecast_cons_12m         16096 non-null  float64
#  3   forecast_meter_rent_12m   16096 non-null  float64
#  4   forecast_price_energy_p1  16096 non-null  float64
#  5   forecast_price_pow_p1     16096 non-null  float64
#  6   has_gas                   16096 non-null  object
#  7   margin_gross_pow_ele      16096 non-null  float64
#  8   margin_net_pow_ele        16096 non-null  float64
#  9   nb_prod_act               16096 non-null  int64
#  10  net_margin                16096 non-null  float64
#  11  num_years_antig           16096 non-null  int64
#  12  origin_up                 16096 non-null  object
#  13  pow_max                   16096 non-null  float64
#  14  days                      16096 non-null  float64
#  15  renewal_days              16096 non-null  float64
#  16  modif_label               16096 non-null  float64
#  17  price_p1_var              16096 non-null  float64
#  18  price_p1_fix              16096 non-null  float64
# dtypes: float64(14), int64(2), object(3)
# memory usage: 2.5+ MB

# %%
#对data和output_data进行合并操作，内连接合并
data = pd.merge(data,output_data,on=['id'],how='inner')
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16096 entries, 0 to 16095
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        16096 non-null  object
#  1   cons_12m                  16096 non-null  float64
#  2   forecast_cons_12m         16096 non-null  float64
#  3   forecast_meter_rent_12m   16096 non-null  float64
#  4   forecast_price_energy_p1  16096 non-null  float64
#  5   forecast_price_pow_p1     16096 non-null  float64
#  6   has_gas                   16096 non-null  object
#  7   margin_gross_pow_ele      16096 non-null  float64
#  8   margin_net_pow_ele        16096 non-null  float64
#  9   nb_prod_act               16096 non-null  int64
#  10  net_margin                16096 non-null  float64
#  11  num_years_antig           16096 non-null  int64
#  12  origin_up                 16096 non-null  object
#  13  pow_max                   16096 non-null  float64
#  14  days                      16096 non-null  float64
#  15  renewal_days              16096 non-null  float64
#  16  modif_label               16096 non-null  float64
#  17  price_p1_var              16096 non-null  float64
#  18  price_p1_fix              16096 non-null  float64
#  19  churn                     16096 non-null  int64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 2.6+ MB

# %%
data.head()
# Out:
#                                  id  cons_12m  forecast_cons_12m  \
# 0  48ada52261e7cf58715202705a0451c9  309275.0          26520.300
# 1  24011ae4ebbe3035111d65fa7c15bc57   15566.0           1213.735
# 2  d29c2c54acc38ff3c0614d0a653813dd    4660.0            189.950
# 3  764c75f661154dac3a6c254cd082ea7d     544.0             47.960
# 4  bba03439a292a1e166f80264c16191cb    1584.0            240.040
#
#    forecast_meter_rent_12m  forecast_price_energy_p1  forecast_price_pow_p1  \
# 0                   359.29                  0.095919              58.995952
# 1                     1.78                  0.114481              40.606701
# 2                    16.27                  0.145711              44.311378
# 3                    38.72                  0.165794              44.311378
# 4                    19.83                  0.146694              44.311378
#
#   has_gas  margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# 0       0                -41.76              -41.76            1     1732.36
# 1       1                 25.44               25.44            2      678.99
# 2       0                 16.38               16.38            1       18.89
# 3       0                 28.60               28.60            1        6.60
# 4       0                 30.22               30.22            1       25.46
#
#    num_years_antig origin_up  pow_max    days  renewal_days  modif_label  \
# 0                3         0  180.000  1460.0        -363.0          1.0
# 1                3         1   43.648  1096.0        -358.0          1.0
# 2                6         2   13.800  2566.0        -365.0          1.0
# 3                6         2   13.856  2192.0        -365.0          1.0
# 4                6         2   13.200  2192.0        -365.0          1.0
#
#    price_p1_var  price_p1_fix  churn
# 0      0.103449     58.956502      0
# 1      0.122856     40.640023      1
# 2      0.149934     44.315416      0
# 3      0.170512     44.385450      0
# 4      0.151210     44.400265      0

# %%
#查看标签情况
f,ax=plt.subplots(1,2,figsize=(18,8))
data['churn'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('churn')
ax[0].set_ylabel('')
sns.countplot('churn',data=data,ax=ax[1])
ax[1].set_title('churn')
plt.show()
# Out:
# C:\Users\xrheng\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#has_gas与标签关系
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['has_gas','churn']].groupby(['has_gas']).mean().plot.bar(ax=ax[0])
ax[0].set_title('churn vs has_gas')
sns.countplot('has_gas',hue='churn',data=data,ax=ax[1])
ax[1].set_title('has_gas:1 vs 0')
plt.show()
# Out:
# C:\Users\xrheng\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data.head()
# Out:
#                                  id  cons_12m  forecast_cons_12m  \
# 0  48ada52261e7cf58715202705a0451c9  309275.0          26520.300
# 1  24011ae4ebbe3035111d65fa7c15bc57   15566.0           1213.735
# 2  d29c2c54acc38ff3c0614d0a653813dd    4660.0            189.950
# 3  764c75f661154dac3a6c254cd082ea7d     544.0             47.960
# 4  bba03439a292a1e166f80264c16191cb    1584.0            240.040
#
#    forecast_meter_rent_12m  forecast_price_energy_p1  forecast_price_pow_p1  \
# 0                   359.29                  0.095919              58.995952
# 1                     1.78                  0.114481              40.606701
# 2                    16.27                  0.145711              44.311378
# 3                    38.72                  0.165794              44.311378
# 4                    19.83                  0.146694              44.311378
#
#   has_gas  margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# 0       0                -41.76              -41.76            1     1732.36
# 1       1                 25.44               25.44            2      678.99
# 2       0                 16.38               16.38            1       18.89
# 3       0                 28.60               28.60            1        6.60
# 4       0                 30.22               30.22            1       25.46
#
#    num_years_antig origin_up  pow_max    days  renewal_days  modif_label  \
# 0                3         0  180.000  1460.0        -363.0          1.0
# 1                3         1   43.648  1096.0        -358.0          1.0
# 2                6         2   13.800  2566.0        -365.0          1.0
# 3                6         2   13.856  2192.0        -365.0          1.0
# 4                6         2   13.200  2192.0        -365.0          1.0
#
#    price_p1_var  price_p1_fix  churn
# 0      0.103449     58.956502      0
# 1      0.122856     40.640023      1
# 2      0.149934     44.315416      0
# 3      0.170512     44.385450      0
# 4      0.151210     44.400265      0

# %%
#data['price_p1_var_Range']=pd.qcut(data['price_p1_var'],5)
#data.groupby(['price_p1_var_Range'])['churn'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d403b_row0_col0 {
#   background-color: #98cc66;
#   color: #000000;
# }
# #T_d403b_row1_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_d403b_row2_col0 {
#   background-color: #e9f466;
#   color: #000000;
# }
# #T_d403b_row3_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d403b_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# </style>
# <table id="T_d403b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >churn</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >price_p1_var_Range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d403b_level0_row0" class="row_heading level0 row0" >(-0.0004000000000000001, 0.123]</th>
#       <td id="T_d403b_row0_col0" class="data row0 col0" >0.101521</td>
#     </tr>
#     <tr>
#       <th id="T_d403b_level0_row1" class="row_heading level0 row1" >(0.123, 0.128]</th>
#       <td id="T_d403b_row1_col0" class="data row1 col0" >0.116207</td>
#     </tr>
#     <tr>
#       <th id="T_d403b_level0_row2" class="row_heading level0 row2" >(0.128, 0.149]</th>
#       <td id="T_d403b_row2_col0" class="data row2 col0" >0.093788</td>
#     </tr>
#     <tr>
#       <th id="T_d403b_level0_row3" class="row_heading level0 row3" >(0.149, 0.151]</th>
#       <td id="T_d403b_row3_col0" class="data row3 col0" >0.091596</td>
#     </tr>
#     <tr>
#       <th id="T_d403b_level0_row4" class="row_heading level0 row4" >(0.151, 0.279]</th>
#       <td id="T_d403b_row4_col0" class="data row4 col0" >0.092265</td>
#     </tr>
#   </tbody>
# </table>

# %%
def qcut_columns(data):
    data['Fare_Range']=pd.qcut(data['Fare'],5)
    data.groupby(['Fare_Range'])['Survived'].mean().to_frame().style.background_gradient(cmap='summer_r')

# %%
data.drop(['cons_12m_Range','price_p1_var_Range'],axis=1,inplace=True)
data.head()
# Out:
#                                  id  cons_12m  forecast_cons_12m  \
# 0  48ada52261e7cf58715202705a0451c9  309275.0          26520.300
# 1  24011ae4ebbe3035111d65fa7c15bc57   15566.0           1213.735
# 2  d29c2c54acc38ff3c0614d0a653813dd    4660.0            189.950
# 3  764c75f661154dac3a6c254cd082ea7d     544.0             47.960
# 4  bba03439a292a1e166f80264c16191cb    1584.0            240.040
#
#    forecast_meter_rent_12m  forecast_price_energy_p1  forecast_price_pow_p1  \
# 0                   359.29                  0.095919              58.995952
# 1                     1.78                  0.114481              40.606701
# 2                    16.27                  0.145711              44.311378
# 3                    38.72                  0.165794              44.311378
# 4                    19.83                  0.146694              44.311378
#
#   has_gas  margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# 0       0                -41.76              -41.76            1     1732.36
# 1       1                 25.44               25.44            2      678.99
# 2       0                 16.38               16.38            1       18.89
# 3       0                 28.60               28.60            1        6.60
# 4       0                 30.22               30.22            1       25.46
#
#    num_years_antig origin_up  pow_max    days  renewal_days  modif_label  \
# 0                3         0  180.000  1460.0        -363.0          1.0
# 1                3         1   43.648  1096.0        -358.0          1.0
# 2                6         2   13.800  2566.0        -365.0          1.0
# 3                6         2   13.856  2192.0        -365.0          1.0
# 4                6         2   13.200  2192.0        -365.0          1.0
#
#    price_p1_var  price_p1_fix  churn
# 0      0.103449     58.956502      0
# 1      0.122856     40.640023      1
# 2      0.149934     44.315416      0
# 3      0.170512     44.385450      0
# 4      0.151210     44.400265      0

# %%
#importing all the required ML packages
from sklearn.linear_model import LogisticRegression #logistic regression
from sklearn import svm #support vector Machine
from sklearn.ensemble import RandomForestClassifier #Random Forest
from sklearn.neighbors import KNeighborsClassifier #KNN
from sklearn.naive_bayes import GaussianNB #Naive bayes
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split #training and testing data split
from sklearn import metrics #accuracy measure
from sklearn.metrics import confusion_matrix #for confusion matrix

# %%
train,test=train_test_split(data,test_size=0.3,random_state=0,stratify=data['churn'])
train_X=train[train.columns[1:]]
train_Y=train[train.columns[:1]]
test_X=test[test.columns[1:]]
test_Y=test[test.columns[:1]]
X=data[data.columns[1:]]
Y=data['churn']

# %%
model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
model.fit(train_X,train_Y)
prediction1=model.predict(test_X)
print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
# Out:
# C:\Users\xrheng\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2012/3391898682.py in <module>
#       1 model=svm.SVC(kernel='rbf',C=1,gamma=0.1)
# ----> 2 model.fit(train_X,train_Y)
#       3 prediction1=model.predict(test_X)
#       4 print('Accuracy for rbf SVM is ',metrics.accuracy_score(prediction1,test_Y))
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     224
#     225         seed = rnd.randint(np.iinfo('i').max)
# --> 226         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     227         # see comment on the other call to np.iinfo in this file
#     228
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     275         self.support_, self.support_vectors_, self._n_support, \
#     276             self.dual_coef_, self.intercept_, self._probA, \
# --> 277             self._probB, self.fit_status_ = libsvm.fit(
#     278                 X, y,
#     279                 svm_type=solver_type, sample_weight=sample_weight,
#
# KeyboardInterrupt:

# %%
model=RandomForestClassifier(n_estimators=100)
model.fit(train_X,train_Y)
prediction7=model.predict(test_X)
print('The accuracy of the Random Forests is',metrics.accuracy_score(prediction7,test_Y))
# Out:
# C:\Users\xrheng\AppData\Local\Temp/ipykernel_2012/920559216.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(train_X,train_Y)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2012/920559216.py in <module>
#       1 model=RandomForestClassifier(n_estimators=100)
# ----> 2 model.fit(train_X,train_Y)
#       3 prediction7=model.predict(test_X)
#       4 print('The accuracy of the Random Forests is',metrics.accuracy_score(prediction7,test_Y))
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
#     389                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     167                                                         indices=indices)
#     168
# --> 169         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     170     else:
#     171         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     392                                            min_impurity_split)
#     393
# --> 394         builder.build(self.tree_, X, y, sample_weight)
#     395
#     396         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 1476788224 bytes

# %%
model=DecisionTreeClassifier()
model.fit(train_X,train_Y)
prediction4=model.predict(test_X)
print('The accuracy of the Decision Tree is',metrics.accuracy_score(prediction4,test_Y))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2012/178858294.py in <module>
#       1 model=DecisionTreeClassifier()
# ----> 2 model.fit(train_X,train_Y)
#       3 prediction4=model.predict(test_X)
#       4 print('The accuracy of the Decision Tree is',metrics.accuracy_score(prediction4,test_Y))
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     392                                            min_impurity_split)
#     393
# --> 394         builder.build(self.tree_, X, y, sample_weight)
#     395
#     396         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:
